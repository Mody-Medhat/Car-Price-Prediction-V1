# %% [markdown]
# ## Import the main Libraries

# %%
## Major Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import scrapy

#from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#from sklearn.preprocessing import OneHotEncoder
#from sklearn.compose import make_column_transformer
#from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score


## sklearn -- metrics
from sklearn.metrics import mean_squared_error, r2_score

## sklearn -- Models
from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge, Lasso, ElasticNet


from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn_features.transformers import DataFrameSelector


## Other
import os, joblib, missingno

# %% [markdown]
# ## 1) Readinig Data

# %%
## load the data Using 'OS'
FILE_PATH = os.path.join(os.getcwd(),'CarData.csv')
## Read the CSV file using pandas
df = pd.read_csv(FILE_PATH)

# %%
## Show the Head of the DF
df.head(15)
# Out:
#            Make                   Model  Year             Engine Fuel Type  \
# 0     Chevrolet                  Cobalt  2008             regular unleaded
# 1        Toyota                  Matrix  2012             regular unleaded
# 2        Subaru                 Impreza  2016             regular unleaded
# 3    Volkswagen                 Vanagon  1991             regular unleaded
# 4          Ford                   F-150  2017     flex-fuel (unleaded/E85)
# 5    Volkswagen                  Rabbit  2008             regular unleaded
# 6       Bentley         Continental GTC  2013  premium unleaded (required)
# 7           BMW                6 Series  2015  premium unleaded (required)
# 8       Maybach                      57  2012  premium unleaded (required)
# 9          Ford          F-150 Heritage  2004             regular unleaded
# 10  Rolls-Royce  Phantom Drophead Coupe  2015  premium unleaded (required)
# 11    Chevrolet                 Equinox  2015             regular unleaded
# 12   Mitsubishi          Eclipse Spyder  2011             regular unleaded
# 13      Ferrari            California T  2015  premium unleaded (required)
# 14         Audi                      Q5  2017  premium unleaded (required)
#
#     Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 0       148.0               4.0            MANUAL  front wheel drive
# 1       132.0               4.0         AUTOMATIC  front wheel drive
# 2       148.0               4.0         AUTOMATIC    all wheel drive
# 3        90.0               4.0            MANUAL   rear wheel drive
# 4       385.0               8.0         AUTOMATIC   four wheel drive
# 5       170.0               5.0            MANUAL  front wheel drive
# 6       500.0               8.0         AUTOMATIC    all wheel drive
# 7       315.0               6.0         AUTOMATIC   rear wheel drive
# 8       543.0              12.0         AUTOMATIC   rear wheel drive
# 9       202.0               6.0            MANUAL   four wheel drive
# 10      453.0              12.0         AUTOMATIC   rear wheel drive
# 11      182.0               4.0         AUTOMATIC    all wheel drive
# 12      162.0               4.0         AUTOMATIC  front wheel drive
# 13      553.0               8.0  AUTOMATED_MANUAL   rear wheel drive
# 14      272.0               6.0         AUTOMATIC    all wheel drive
#
#     Number of Doors Vehicle Size       Vehicle Style  highway MPG  city mpg  \
# 0               2.0      Compact               Coupe           33        24
# 1               4.0      Compact       4dr Hatchback           32        25
# 2               4.0      Compact       4dr Hatchback           37        28
# 3               3.0        Large   Passenger Minivan           18        16
# 4               4.0        Large     Crew Cab Pickup           21        15
# 5               4.0      Compact       4dr Hatchback           29        22
# 6               2.0      Midsize         Convertible           24        14
# 7               2.0      Midsize               Coupe           32        21
# 8               4.0        Large               Sedan           16        10
# 9               2.0        Large  Regular Cab Pickup           18        13
# 10              2.0        Large         Convertible           19        11
# 11              4.0      Compact             4dr SUV           29        20
# 12              2.0      Compact         Convertible           27        20
# 13              2.0      Compact         Convertible           23        16
# 14              4.0      Midsize             4dr SUV           26        18
#
#     Popularity    MSRP
# 0         1385   14410
# 1         2031   19685
# 2          640   19795
# 3          873    2000
# 4         5657   56260
# 5          873   17575
# 6          520  191400
# 7         3916   76100
# 8           67  379050
# 9         5657   26030
# 10          86  479775
# 11        1385   33670
# 12         436   27999
# 13        2774  198973
# 14        3105   53200

# %%
#df[df.driven_wheels == 'all_wheel_drive'].sample(2)

# %%
#df[df.driven_wheels == 'four_wheel_drive'].sample(2)

# %% [markdown]
# **Number of `rows` and `colmans`**

# %%
df.shape
# Out:
# (11914, 15)

# %% [markdown]
# ## Dataset Columns Description
# `make`: make of a car (BMW, Toyota, and so on)
#
# `model`: model of a car
#
# `year`: year when the car was manufactured
#
# `engine_fuel_type`: type of fuel the engine needs (diesel, electric, and so on)
#
# `engine_hp`: horsepower of the engine
#
# `engine_cylinders`: number of cylinders in the engine
#
# `transmission_type`: type of transmission (automatic or manual)
#
# `driven_wheels`: front, rear, all
#
# `number_of_doors`: number of doors a car has
#
# `market_category`: luxury, crossover, and so on
#
# `vehicle_size`: compact, midsize, or large
#
# `vehicle_style`: sedan or convertible
#
# `highway_mpg`: miles per gallon (mpg) on the highway
#
# `city_mpg`: miles per gallon in the city
#
# `popularity`: number of times the car was mentioned in a Twitter stream
#
# `msrp`: manufacturer’s suggested retail price

# %%
## Show some information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Vehicle Size       11914 non-null  object
#  10  Vehicle Style      11914 non-null  object
#  11  highway MPG        11914 non-null  int64
#  12  city mpg           11914 non-null  int64
#  13  Popularity         11914 non-null  int64
#  14  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 1.4+ MB

# %%
## Show number of unique value en each column
## Print top 5 largest value   
for col in df.columns:
    print( col,':', df[col].nunique() )
    print(df[col].value_counts().nlargest(5))
    print('\n' + '*' * 26 + '\n')
# Out:
# Make : 48
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Name: Make, dtype: int64
#
# **************************
#
# Model : 915
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
# Name: Model, dtype: int64
#
# **************************
#
# Year : 28
# 2015    2170
# 2016    2157
# 2017    1668
# 2014     589
# 2012     387
# Name: Year, dtype: int64
#
# **************************
#
# Engine Fuel Type : 10
# regular unleaded                  7172
# premium unleaded (required)       2009
# premium unleaded (recommended)    1523
# flex-fuel (unleaded/E85)           899
# diesel                             154
# Name: Engine Fuel Type, dtype: int64
#
# **************************
#
# Engine HP : 356
# 200.0    456
# 170.0    351
# 210.0    320
# 240.0    268
# 285.0    246
# Name: Engine HP, dtype: int64
#
# **************************
#
# Engine Cylinders : 9
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# Name: Engine Cylinders, dtype: int64
#
# **************************
#
# Transmission Type : 5
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: Transmission Type, dtype: int64
#
# **************************
#
# Driven_Wheels : 4
# front wheel drive    4787
# rear wheel drive     3371
# all wheel drive      2353
# four wheel drive     1403
# Name: Driven_Wheels, dtype: int64
#
# **************************
#
# Number of Doors : 3
# 4.0    8353
# 2.0    3160
# 3.0     395
# Name: Number of Doors, dtype: int64
#
# **************************
#
# Vehicle Size : 3
# Compact    4764
# Midsize    4373
# Large      2777
# Name: Vehicle Size, dtype: int64
#
# **************************
#
# Vehicle Style : 16
# Sedan            3048
# 4dr SUV          2488
# Coupe            1211
# Convertible       793
# 4dr Hatchback     702
# Name: Vehicle Style, dtype: int64
#
# **************************
#
# highway MPG : 59
# 24    876
# 23    801
# 26    778
# 22    753
# 25    731
# Name: highway MPG, dtype: int64
#
# **************************
#
# city mpg : 69
# 17    1230
# 16    1106
# 15    1038
# 18     997
# 19     841
# Name: city mpg, dtype: int64
#
# **************************
#
# Popularity : 48
# 1385    1123
# 5657     881
# 873      809
# 2031     746
# 1851     626
# Name: Popularity, dtype: int64
#
# **************************
#
# MSRP : 6049
# 2000     1036
# 29995      19
# 25995      19
# 27995      16
# 20995      16
# Name: MSRP, dtype: int64
#
# **************************

# %% [markdown]
# ## 2) Cleaning

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# >**We notice that there are `some inconsistencies` in this dataset: the column names sometimes have spaces and sometimes
# have underscores (_)**

# %%
## Lowercase the column names, and replace spaces with underscores
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
## List of column names with oject tybe
string_columns = list(df.dtypes[df.dtypes == 'object'].index)
print(string_columns)
# Out:
# ['make', 'model', 'engine_fuel_type', 'transmission_type', 'driven_wheels', 'vehicle_size', 'vehicle_style']

# %%
## Lowercase and replace spaces with underscores for values in all string columns
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %% [markdown]
# **Rename the `msrp`column to meaningful name `price`**

# %%
df.rename(columns = {'msrp': 'price'}, inplace = True)

# %% [markdown]
# **Checking for `duplicates data`**

# %%
df.loc[df.duplicated()]
# Out:
#                 make            model  year             engine_fuel_type  \
# 332            volvo              850  1995             regular_unleaded
# 672           toyota           tacoma  2017             regular_unleaded
# 683           toyota            camry  2017             regular_unleaded
# 708       volkswagen          vanagon  1991             regular_unleaded
# 812           toyota           tacoma  2016             regular_unleaded
# ...              ...              ...   ...                          ...
# 11873           ford            e-250  1997             regular_unleaded
# 11874           ford  transit_connect  2017     flex-fuel_(unleaded/e85)
# 11879          honda            pilot  2017             regular_unleaded
# 11896  mercedes-benz          e-class  2016                       diesel
# 11905            bmw         4_series  2015  premium_unleaded_(required)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 332        168.0               5.0            manual  front_wheel_drive
# 672        278.0               6.0         automatic   four_wheel_drive
# 683        178.0               4.0         automatic  front_wheel_drive
# 708         90.0               4.0            manual   rear_wheel_drive
# 812        278.0               6.0         automatic   four_wheel_drive
# ...          ...               ...               ...                ...
# 11873      200.0               6.0         automatic   rear_wheel_drive
# 11874      169.0               4.0         automatic  front_wheel_drive
# 11879      280.0               6.0         automatic    all_wheel_drive
# 11896      195.0               4.0         automatic    all_wheel_drive
# 11905      240.0               4.0         automatic   rear_wheel_drive
#
#        number_of_doors vehicle_size        vehicle_style  highway_mpg  \
# 332                4.0      midsize                sedan           26
# 672                4.0      compact      crew_cab_pickup           23
# 683                4.0      midsize                sedan           33
# 708                3.0        large    passenger_minivan           18
# 812                4.0      compact  extended_cab_pickup           23
# ...                ...          ...                  ...          ...
# 11873              3.0      midsize            cargo_van           17
# 11874              4.0      compact        cargo_minivan           27
# 11879              4.0      midsize              4dr_suv           26
# 11896              4.0      midsize                sedan           38
# 11905              2.0      midsize                coupe           35
#
#        city_mpg  popularity  price
# 332          18         870   2000
# 672          18        2031  35315
# 683          24        2031  26310
# 708          16         873   2000
# 812          18        2031  33310
# ...         ...         ...    ...
# 11873        12        5657   2000
# 11874        20        5657  22900
# 11879        18        2202  39255
# 11896        27         617  55150
# 11905        23        3916  40750
#
# [720 rows x 15 columns]

# %% [markdown]
# **Dop `duplicates data`**

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity  price
# 0      compact              coupe           33        24        1385  14410
# 1      compact      4dr_hatchback           32        25        2031  19685
# 2      compact      4dr_hatchback           37        28         640  19795
# 3        large  passenger_minivan           18        16         873   2000
# 4        large    crew_cab_pickup           21        15        5657  56260

# %% [markdown]
# ## 3) Data Analysis

# %% [markdown]
# **Describe of `the Numerical` Features**

# %%
df.describe()
# Out:
#                year     engine_hp  engine_cylinders  number_of_doors  \
# count  11194.000000  11125.000000      11164.000000     11188.000000
# mean    2010.715026    253.390562          5.665801         3.454058
# std        7.226875    110.170627          1.797210         0.872972
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    172.000000          4.000000         2.000000
# 50%     2015.000000    239.000000          6.000000         4.000000
# 75%     2016.000000    303.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway_mpg      city_mpg    popularity         price
# count  11194.000000  11194.000000  11194.000000  1.119400e+04
# mean      26.610238     19.732089   1557.964445  4.193329e+04
# std        8.979206      9.179458   1445.449268  6.154731e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.159925e+04
# 50%       25.000000     18.000000   1385.000000  3.067500e+04
# 75%       30.000000     22.000000   2009.000000  4.303875e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# **Describe of `the Object` Features**

# %%
df.describe(include = ['O'])
# Out:
#              make           model  engine_fuel_type transmission_type  \
# count       11194           11194             11191             11194
# unique         48             914                10                 5
# top     chevrolet  silverado_1500  regular_unleaded         automatic
# freq         1083             156              6653              7928
#
#             driven_wheels vehicle_size vehicle_style
# count               11194        11194         11194
# unique                  4            3            16
# top     front_wheel_drive      compact         sedan
# freq                 4350         4393          2840

# %% [markdown]
# **Unique values in `make column` and their counts**

# %%
Car_Make = df['make'].value_counts()
Car_Make
# Out:
# chevrolet        1083
# ford              824
# toyota            716
# volkswagen        568
# nissan            551
# dodge             528
# gmc               482
# honda             433
# mazda             412
# cadillac          396
# suzuki            342
# mercedes-benz     341
# infiniti          328
# bmw               324
# audi              321
# volvo             266
# hyundai           259
# acura             246
# subaru            239
# kia               229
# mitsubishi        208
# lexus             202
# buick             190
# chrysler          187
# pontiac           181
# lincoln           160
# land_rover        139
# porsche           136
# oldsmobile        132
# saab              109
# aston_martin       91
# bentley            74
# plymouth           71
# ferrari            69
# fiat               62
# scion              60
# maserati           55
# lamborghini        52
# rolls-royce        31
# lotus              28
# tesla              18
# hummer             17
# maybach            16
# mclaren             5
# alfa_romeo          5
# bugatti             3
# genesis             3
# spyker              2
# Name: make, dtype: int64

# %%
plt.figure(figsize=(50,20))
sns.countplot('make' , data = df , order=Car_Make.index)
plt.title('CountPlot of "Car Make" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Make', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')

## To show the percentage of each bar
for i in range(len(Car_Make)):  ## loop over the numbers of categories (number of bars)
    each_count = Car_Make.values[i]
    each_text = f'{((100*each_count)/ len(df)):.2f}%'
    plt.text(x=i, y=each_count+10, s=each_text, c='b', fontsize=14, ha='center')
# Out:
# C:\Users\org\anaconda3\envs\RegPro\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Checking relationship of `make` with `log_price`**

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='make',y='price',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# **Relationship of `log_price` with `engine_fuel_type`, `year` and `make` mixed**

# %%
ax=sns.relplot(x='make',y='price',data=df,hue='engine_fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# **Checking relationship of `highway_mpg` with `log_price`**

# %%
sns.relplot(x='highway_mpg',y='price',data=df,height=7,aspect=1.5)

# %% [markdown]
# **Checking relationship of `city_mpg` with `log_price`**

# %%
sns.relplot(x='city_mpg',y='price',data=df,height=7,aspect=1.5)

# %% [markdown]
# **Checking relationship of `engine_fuel_type` with `log_price`**

# %%
plt.subplots(figsize=(30,15))
sns.boxplot(x='engine_fuel_type',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='engine_fuel_type', ylabel='price'>

# %% [markdown]
# **Histogram Distr. of `Numerical Features` in Dataset**

# %%
df.hist(bins=30, figsize=(20, 10))
plt.show()

# %% [markdown]
# >**Cut this Numerical Feature `price` to Categorical One**

# %%
car_value_bins = pd.cut(x=df['price'], 
                          bins=[-np.inf, 10000, 20000, 30000, 40000, 50000, np.inf],
                          labels=['0-10k', '10k-20k', '30k-40k', '40k-50k', '50k-60k', '60k<'])


## Countplot for the above chunks
plt.figure(figsize=(10, 6))
sns.countplot(x=car_value_bins)
plt.title('CountPlot of Car Value Bins in Dataset', fontsize=14, c='k')
plt.xlabel('Car Value Bins', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
plt.show()

# %% [markdown]
# >**We notice that most of cars in the data have price from `30k to 50k`**

# %%
df.corr()
# Out:
#                       year  engine_hp  engine_cylinders  number_of_doors  \
# year              1.000000   0.336117         -0.034402         0.247207
# engine_hp         0.336117   1.000000          0.788439        -0.129489
# engine_cylinders -0.034402   0.788439          1.000000        -0.150167
# number_of_doors   0.247207  -0.129489         -0.150167         1.000000
# highway_mpg       0.244912  -0.415522         -0.617499         0.114615
# city_mpg          0.188413  -0.446891         -0.598751         0.120684
# popularity        0.085986   0.042433          0.038330        -0.057451
# price             0.209598   0.659178          0.538764        -0.145014
#
#                   highway_mpg  city_mpg  popularity     price
# year                 0.244912  0.188413    0.085986  0.209598
# engine_hp           -0.415522 -0.446891    0.042433  0.659178
# engine_cylinders    -0.617499 -0.598751    0.038330  0.538764
# number_of_doors      0.114615  0.120684   -0.057451 -0.145014
# highway_mpg          1.000000  0.886306   -0.017043 -0.166650
# city_mpg             0.886306  1.000000   -0.000427 -0.162362
# popularity          -0.017043 -0.000427    1.000000 -0.048319
# price               -0.166650 -0.162362   -0.048319  1.000000

# %%
plt.figure(figsize=(15,8))
_=sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# ## 4) analysis (price)

# %%
plt.figure(figsize=(15, 7))

sns.histplot(df.price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %% [markdown]
# >**This is a `long tail` distribution, which is a typical situation for many items with low prices and very few expensive ones.**

# %%
plt.figure(figsize=(14, 7))

sns.histplot(df.price[df.price < 80000], bins=40)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %% [markdown]
# >**The `long tail` makes it quite difficult for us to see the distribution, but it has an even stronger effect on a model: such distribution can greatly confuse the model, so it won’t learn well enough.**
# >>**we hande it by using `log transformation`.**

# %% [markdown]
# ## 5) Log Transformation For Price

# %% [markdown]
# **Add New Column `log_price` and plt it**

# %%
df['log_price'] = np.log1p(df.price)

plt.figure(figsize=(14, 7))

sns.histplot(df.log_price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Distribution of prices after log tranformation')

plt.show()

# %% [markdown]
# >**The effect of the `long tail` is removed**
#
# >**The `price+1` part is important in cases that have zeros. The logarithm of zero is minus infinity, but the logarithm of one is zero.**

# %% [markdown]
# ## 5) Check The Nulls

# %%
df.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_fuel_type      3
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# driven_wheels         0
# number_of_doors       6
# vehicle_size          0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# popularity            0
# price                 0
# log_price             0
# dtype: int64

# %%
## check nulls using (missingno) library
missingno.bar(df);

# %% [markdown]
# >**It seems that Dataset is a contains 11914 instances and `3742` null values in `market_category` , `3` null values in `engine_fuel_type` , `69` null values in `engine_hp` and `30` null values in `engine_cylinders` features.**

# %% [markdown]
# **File the null values in numerical columns `engine_hp` , `engine_cylinders` and `number_of_doors`**

# %%
df['engine_hp'] = df['engine_hp'].fillna(df['engine_hp'].median())
df['engine_cylinders'] = df['engine_cylinders'].fillna(df['engine_cylinders'].median())
df['number_of_doors'] = df['number_of_doors'].fillna(df['number_of_doors'].median())

# %% [markdown]
# ## 6) Applying Train Test Split

# %%
#x = df.drop(['price' , 'log_price' , 'market_category' ] , axis=1)
X = df.drop(['price' , 'log_price' ,'popularity'] , axis=1)
y = df['log_price']

# %%
## Random split the dataset to two sets (train_set, test_set)
## For validation ---  I will use Cross Validation

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=True, random_state=42)

## Check Shapes of these Sets
print('X_train shape -- ', X_train.shape)
print('y_train shape -- ', y_train.shape)
print('X_test shape -- ', X_test.shape)
print('y_test shape -- ', y_test.shape)
# Out:
# X_train shape --  (9514, 13)
# y_train shape --  (9514,)
# X_test shape --  (1680, 13)
# y_test shape --  (1680,)

# %% [markdown]
# **Show the categorical columes**

# %%
## Separete the columns according to type (numerical or categorical)
num_cols = [col for col in X_train.columns if X_train[col].dtype in ['float32', 'float64', 'int32', 'int64']]
categ_cols = [col for col in X_train.columns if X_train[col].dtype not in ['float32', 'float64', 'int32', 'int64']]


print('Numerical Columns : \n', num_cols)
print('**'*40)
print('Categorical Columns : \n', categ_cols)
# Out:
# Numerical Columns :
#  ['year', 'engine_hp', 'engine_cylinders', 'number_of_doors', 'highway_mpg', 'city_mpg']
# ********************************************************************************
# Categorical Columns :
#  ['make', 'model', 'engine_fuel_type', 'transmission_type', 'driven_wheels', 'vehicle_size', 'vehicle_style']

# %% [markdown]
# ## 7) Handling Categorical Variables

# %% [markdown]
# **handle `categorical columns` ( to be transformed into numerical form)**

# %%
#ohe=OneHotEncoder()
#ohe.fit(x[['make','model','engine_fuel_type','transmission_type','driven_wheels','vehicle_size','vehicle_style']])

# %% [markdown]
# **Creating a `column transformer` to transform categorical columns**

# %%
'''column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),
                                    ['make','model','engine_fuel_type','transmission_type','driven_wheels','vehicle_size','vehicle_style']),
                                    remainder='passthrough')'''
# Out:
# "column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),\n                                    ['make','model','engine_fuel_type','transmission_type','driven_wheels','vehicle_size','vehicle_style']),\n                                    remainder='passthrough')"

# %%
## We can get much much easier like the following
## numerical pipeline
num_pipeline = Pipeline([
                        ('selector', DataFrameSelector(num_cols)),    ## select only these columns
                        ('imputer', SimpleImputer(strategy='median')),
                        ('scaler', StandardScaler())
                        ])

## categorical pipeline
categ_pipeline = Pipeline(steps=[
            ('selector', DataFrameSelector(categ_cols)),    ## select only these columns
            ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('OHE', OneHotEncoder(sparse=False , handle_unknown='ignore'))])

## concatenate both two pipelines
total_pipeline = FeatureUnion(transformer_list=[
                                            ('num_pipe', num_pipeline),
                                            ('categ_pipe', categ_pipeline)
                                               ]
                             )
## deal with (total_pipeline) as an instance -- fit and transform to train dataset and transform only to other datasets
X_train_final = total_pipeline.fit_transform(X_train)
X_test_final = total_pipeline.transform(X_test)                 ### Every thing is processed :D

# %%
X_train_final.shape , X_test_final.shape
# Out:
# ((9514, 995), (1680, 995))

# %% [markdown]
# **Linear Regression Model**

# %%
lr = LinearRegression()

# %%
lr.fit(X_train_final, y_train)
# Out:
# LinearRegression()

# %%
## Check scores of this Model (RMSE) using (cross_val_score)
rmse_scores_lin = cross_val_score(estimator=lr, X=X_train_final, y=y_train, 
                               cv=5, scoring='neg_mean_squared_error', n_jobs=-1)  ## sklearn deals with error as negative
rmse_scores_lin = -1 * rmse_scores_lin   ## we want it positive
rmse_scores_lin = np.sqrt(rmse_scores_lin)
rmse_scores_lin.mean()
# Out:
# 1346353155.3580742

# %%
y_pred_lin = cross_val_predict(estimator=lr, X=X_train_final, y=y_train, cv=5, method='predict', n_jobs=-1)
rmse_pred_lin = np.sqrt(mean_squared_error(y_train, y_pred_lin))
rmse_pred_lin
# Out:
# 2196742977.4275064

# %%
## Check scores of this Model (RMSE) using (cross_val_score)
rmse_scores_lin = cross_val_score(estimator=lr, X=X_train_final, y=y_train, 
                               cv=5, scoring='neg_mean_squared_error', n_jobs=-1)  ## sklearn deals with error as negative
rmse_scores_lin = -1 * rmse_scores_lin   ## we want it positive
rmse_scores_lin = np.sqrt(rmse_scores_lin)
print(f'RMSE Scores Using LinearRegression --- {np.round(rmse_scores_lin, 4)}')
print(f'Mean of RMSE Scores Using LinearRegression --- {rmse_scores_lin.mean():.4f}')

print('****'*30)

## Get Prediction using (cross_val_predict)
y_pred_lin = cross_val_predict(estimator=lr, X=X_train_final, y=y_train, cv=5, method='predict', n_jobs=-1)
## You can check the (RMSE) using what model predicts and compare it with the Mean of above result -- almost the same
## take care of this point --> don't use .predict when you are using (crossValidation)
rmse_pred_lin = np.sqrt(mean_squared_error(y_train, y_pred_lin))
print(f'RMSE after prediction Using LinearRegression --- {rmse_pred_lin:.4f}')  ## almost the same result :D
# Out:
# RMSE Scores Using LinearRegression --- [1.22183590e+08 6.06474836e+08 3.52201850e+08 1.20805315e+08
#  1.30473966e+08]
# Mean of RMSE Scores Using LinearRegression --- 266427911.5246
# ************************************************************************************************************************
# RMSE after prediction Using LinearRegression --- 328162070.8842

# %%
##y_pred = lr.predict(X_test_final)

# %%
''''def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)'''

# %%
#rmse(y_test,y_pred)

# %% [markdown]
# **Making a pipeline**

# %% [markdown]
# **Checking R2 Score**

# %%
i = 10000
ad = df.iloc[i].to_dict()
ad
# Out:
# {'make': 'lincoln',
#  'model': 'mkz',
#  'year': 2017,
#  'engine_fuel_type': 'premium_unleaded_(recommended)',
#  'engine_hp': 245.0,
#  'engine_cylinders': 4.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 4.0,
#  'vehicle_size': 'midsize',
#  'vehicle_style': 'sedan',
#  'highway_mpg': 31,
#  'city_mpg': 21,
#  'popularity': 61,
#  'price': 47670,
#  'log_price': 10.772078525532862}

# %%
test1 = {
 'make': 'bmw',
 'model': 'm3',
 'year': 2023,
 'engine_fuel_type': 'natural_gas',
 'engine_hp': 503.0,
 'engine_cylinders': 6.0,
 'transmission_type': 'automatic',
 'driven_wheels': 'four_wheel_drive',
 'number_of_doors': 4.0,
 'vehicle_size': 'compact',
 'vehicle_style': 'sedan'
}

# %%
test = {
 'make': 'volvo',
 'model': '240',
 'year': 1993,
 'engine_fuel_type': 'regular_unleaded',
 'engine_hp': 114.0,
 'engine_cylinders': 4.0,
 'transmission_type': 'manual',
 'driven_wheels': 'rear_wheel_drive',
 'number_of_doors': 4.0,
 'market_category': 'luxury',
 'vehicle_size': 'midsize',
 'vehicle_style': 'sedan',
 'highway_mpg': 26,
 'city_mpg': 19,
 'popularity': 870,
 'price': 2000,
 'log_price': 7.601402334583733
}

# %%
 X_test = pd.DataFrame([ad])

# %%
#X_test = pd.DataFrame([test])

# %%
X_test_final = total_pipeline.transform(X_test)                 ### Every thing is processed :D

# %%
y_pred = lr.predict(X_test_final)
y_pred
# Out:
# array([10.74497986])

# %%
suggestion = np.expm1(y_pred)
suggestion
# Out:
# array([46395.52570662])

# %%
#import pickle

# %%
#pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
## Download using joblib
joblib.dump(lr, 'LinearRegressionModel.pkl')
# Out:
# ['LinearRegressionModel.pkl']

# %%
## to load this pretrained Model
loaded_model = joblib.load('LinearRegressionModel.pkl')
loaded_model
# Out:
# LinearRegression()
